# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
cardiodata= pd.read_csv("Cardiotocographic4.csv")

# %%
cardiodata
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
cardiodata.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2105.000000  2106.000000  2126.000000  2126.000000  2126.000000
# mean    133.343598     0.003219     0.009894     0.004391     0.001895
# std      11.270154     0.004391     0.067540     0.003340     0.003343
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001851     0.000000
# 50%     133.000000     0.001634     0.000000     0.004484     0.000000
# 75%     140.000000     0.005650     0.002567     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2105.000000  2105.000000  2126.000000  2126.000000  2126.000000
# mean      0.000003     0.000175    46.995984     1.364378    10.285964
# std       0.000142     0.000840    18.813973     1.173632    21.205041
# ...

# %%
cardiodata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2105 non-null   float64
#  1   AC        2106 non-null   float64
#  2   FM        2126 non-null   float64
#  3   UC        2126 non-null   float64
#  4   DL        2126 non-null   float64
#  5   DS        2105 non-null   float64
#  6   DP        2105 non-null   float64
#  7   ASTV      2126 non-null   float64
#  8   MSTV      2126 non-null   float64
#  9   ALTV      2126 non-null   float64
#  10  MLTV      2105 non-null   float64
#  11  Width     2105 non-null   float64
#  12  Tendency  2105 non-null   float64
#  13  NSP       2105 non-null   float64
# dtypes: float64(14)
# memory usage: 232.7 KB

# %%
cardiodata.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
cardiodata['LB'].fillna(cardio['LB'].mean(),inplace=True)
cardiodata['AC'].fillna(cardio['AC'].mean(),inplace=True)
cardiodata['DS'].fillna(cardio['DS'].mean(),inplace=True)
cardiodata['DP'].fillna(cardio['DP'].mean(),inplace=True)
cardiodata['MLTV'].fillna(cardio['MLTV'].mean(),inplace=True)
cardiodata['Width'].fillna(cardio['Width'].mean(),inplace=True)
cardiodata['Tendency'].fillna(cardio['Tendency'].mean(),inplace=True)
cardiodata['NSP'].fillna(cardio['NSP'].mean(),inplace=True)

# %%
cardiodata.isnull().sum()
# Out:
# LB          0
# AC          0
# FM          0
# UC          0
# DL          0
# DS          0
# DP          0
# ASTV        0
# MSTV        0
# ALTV        0
# MLTV        0
# Width       0
# Tendency    0
# NSP         0
# dtype: int64

# %%
sns.heatmap(cardiodata)
plt.show()

# %%
cardiodata[cardiodata.duplicated()]
# Out:
#          LB        AC   FM        UC   DL   DS   DP  ASTV  MSTV  ALTV  MLTV  \
# 1115  122.0  0.000000  0.0  0.000000  0.0  0.0  0.0  19.0   1.9   0.0  15.1
# 1458  148.0  0.004717  0.0  0.002358  0.0  0.0  0.0  40.0   0.9   0.0  10.6
#
#       Width  Tendency  NSP
# 1115   39.0       0.0  1.0
# 1458   35.0       0.0  1.0

# %%
cardiodata.drop_duplicates(inplace=True)

# %%
cardiodata.duplicated().sum()
# Out:
# 0

# %%
cardiodata
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
cardiodata.hist(figsize=(10,10))
plt.tight_layout()
plt.show()

# %%
sns.pairplot(cardiodata.iloc[:,:])

# %%
cardiodata.select_dtypes(include=['int64', 'float64']).boxplot(figsize=(20, 20))
plt.show()

# %%
cardiodata.corr()
# Out:
#                 LB        AC        FM        UC        DL        DS  \
# LB        1.000000 -0.063452  0.018809 -0.166642 -0.126557 -0.005439
# AC       -0.063452  1.000000  0.009406  0.071552 -0.093330 -0.033109
# FM        0.018809  0.009406  1.000000 -0.053386  0.009641  0.029896
# UC       -0.166642  0.071552 -0.053386  1.000000  0.189737 -0.006942
# DL       -0.126557 -0.093330  0.009641  0.189737  1.000000  0.058429
# DS       -0.005439 -0.033109  0.029896 -0.006942  0.058429  1.000000
# DP       -0.047726 -0.083330  0.121248  0.070348  0.144853  0.004282
# ASTV      0.241666 -0.231058 -0.032838 -0.182379 -0.069907  0.008414
# MSTV     -0.169224  0.133903  0.017061  0.189685  0.410216  0.016079
# ALTV      0.210673 -0.271204 -0.012005 -0.227881 -0.187275 -0.004400
# MLTV     -0.003225 -0.104658 -0.006156 -0.048754 -0.164942  0.034366
# Width    -0.118375  0.234720  0.097125  0.106550  0.408427  0.040831
# Tendency  0.237112  0.031896 -0.018408 -0.066949 -0.023759 -0.015408
# ...

# %%
sns.heatmap(cardiodata.corr(),annot=True)
# Out:
# <Axes: >

# %%
#Normalization of the data

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
mn = MinMaxScaler()

# %%
cardiodata.columns
# Out:
# Index(['LB', 'AC', 'FM', 'UC', 'DL', 'DS', 'DP', 'ASTV', 'MSTV', 'ALTV',
#        'MLTV', 'Width', 'Tendency', 'NSP'],
#       dtype='object')

# %%
minmax_scaled = pd.DataFrame(mn.fit_transform(cardiodata), columns=cardiodata.columns)
minmax_scaled # converted value is in range of 0 and 1
# Out:
#             LB        AC        FM        UC        DL        DS        DP  \
# 0     0.420317  0.333333  0.333333  0.332212  0.333461  0.333333  0.333333
# 1     0.494319  0.443609  0.333333  0.474211  0.402560  0.333333  0.333333
# 2     0.500486  0.390761  0.333333  0.517081  0.405430  0.333333  0.333333
# 3     0.506653  0.377599  0.333333  0.504533  0.388935  0.333333  0.333333
# 4     0.494000  0.445944  0.333333  0.513468  0.333461  0.333333  0.333333
# ...        ...       ...       ...       ...       ...       ...       ...
# 2119  0.543654  0.333333  1.000000  0.497496  0.333461  0.333333  0.333333
# 2120  0.543654  0.346723  0.333333  0.487558  0.333461  0.333333  0.333333
# 2121  0.543654  0.350280  0.333333  0.484965  0.333461  0.333333  0.333333
# 2122  0.543654  0.345068  0.333333  0.468210  0.333461  0.333333  0.333333
# 2123  0.555987  0.361259  0.333203  0.512004  0.333461  0.333333  0.333333
#
# ...

# %%
# Standardization
sc = StandardScaler()

# %%
scaled_data = pd.DataFrame(sc.fit_transform(cardiodata),columns=cardiodata.columns)
scaled_data
# Out:
#             LB        AC         FM        UC        DL        DS        DP  \
# 0    -1.190215 -0.736726  -0.146604 -1.315619 -0.567499 -0.017828 -0.209763
# 1    -0.119719  0.722996  -0.146604  0.594666  0.386682 -0.017828 -0.209763
# 2    -0.030511  0.023445  -0.146604  1.171401  0.426307 -0.017828 -0.209763
# 3     0.058697 -0.150782  -0.146604  1.002588  0.198533 -0.017828 -0.209763
# 4    -0.124337  0.753902  -0.146604  1.122795 -0.567499 -0.017828 -0.209763
# ...        ...       ...        ...       ...       ...       ...       ...
# 2119  0.593945 -0.736726  14.082826  0.907925 -0.567499 -0.017828 -0.209763
# 2120  0.593945 -0.559490  -0.146604  0.774226 -0.567499 -0.017828 -0.209763
# 2121  0.593945 -0.512401  -0.146604  0.739342 -0.567499 -0.017828 -0.209763
# 2122  0.593945 -0.581389  -0.146604  0.513936 -0.567499 -0.017828 -0.209763
# 2123  0.772361 -0.367079  -0.149380  1.103098 -0.567499 -0.017828 -0.209763
#
# ...
